# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sn

# %%
carros=pd.read_csv(r"C:\Users\Daniel\Desktop\Data Science\PythonDataAnalysis\Correlacao-master\auto-mpg.data")

# %%
carros
# Out:
#     18.0   8   307.0      130.0      3504.      12.0   70  1\t"chevrolet chevelle malibu"
# 0    15.0   8   350.0      165.0      3693.      11...
# 1    18.0   8   318.0      150.0      3436.      11...
# 2    16.0   8   304.0      150.0      3433.      12...
# 3    17.0   8   302.0      140.0      3449.      10...
# 4    15.0   8   429.0      198.0      4341.      10...
# ..                                                 ...
# 392  27.0   4   140.0      86.00      2790.      15...
# 393  44.0   4   97.00      52.00      2130.      24...
# 394  32.0   4   135.0      84.00      2295.      11...
# 395  28.0   4   120.0      79.00      2625.      18...
# 396  31.0   4   119.0      82.00      2720.      19...
#
# [397 rows x 1 columns]

# %%
carros=pd.DataFrame(carros)

# %%
carros=pd.read_csv(r"C:\Users\Daniel\Desktop\Data Science\PythonDataAnalysis\Correlacao-master\auto-mpg.data", delim_whitespace=True, header=None,
            names = ['mpg', 'cylinders', 'displacement','horsepower',
            'weight', 'acceleration', 'model_year', 'origin', 'name'],
            na_values='?')

# %%
carros
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
sn.heatmap(carros.isnull(),cbar=False, yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
carros.index=carros['name']

# %%
carros
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0  3504.0
# buick skylark 320          15.0          8         350.0       165.0  3693.0
# plymouth satellite         18.0          8         318.0       150.0  3436.0
# amc rebel sst              16.0          8         304.0       150.0  3433.0
# ford torino                17.0          8         302.0       140.0  3449.0
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0  2790.0
# vw pickup                  44.0          4          97.0        52.0  2130.0
# dodge rampage              32.0          4         135.0        84.0  2295.0
# ford ranger                28.0          4         120.0        79.0  2625.0
# chevy s-10                 31.0          4         119.0        82.0  2720.0
#
# ...

# %%
carros.drop(['name'],axis=1)
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0  3504.0
# buick skylark 320          15.0          8         350.0       165.0  3693.0
# plymouth satellite         18.0          8         318.0       150.0  3436.0
# amc rebel sst              16.0          8         304.0       150.0  3433.0
# ford torino                17.0          8         302.0       140.0  3449.0
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0  2790.0
# vw pickup                  44.0          4          97.0        52.0  2130.0
# dodge rampage              32.0          4         135.0        84.0  2295.0
# ford ranger                28.0          4         120.0        79.0  2625.0
# chevy s-10                 31.0          4         119.0        82.0  2720.0
#
# ...

# %%
sn.distplot(carros['mpg'], kde =False).set_title("Histogram of age")
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Histogram of age')

# %%
sn.boxplot(carros['mpg'])
# Out:
# C:\Users\Daniel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
g = sn.FacetGrid(carros, row = "mpg")
g = g.map(pt.hist, "weight")
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] Foi forçado o cancelamento de uma conexão existente pelo host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
carros.corr().style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] Foi forçado o cancelamento de uma conexão existente pelo host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Daniel\anaconda3\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
carros.describe() #variavevis numericas
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# ...

# %%
carros.describe(include=['O']) #variaveis categoricas
# Out:
#               name
# count          398
# unique         305
# top     ford pinto
# freq             6
